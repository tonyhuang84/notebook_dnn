# %% [markdown]
# source: https://github.com/udacity/self-driving-car-sim

# %% [markdown]
# ## Download prebuild simulator
# ![image.png](attachment:image.png)
#
# * (Linux version) File name: beta_simulator_linux.zip
# * Unzip it

# %% [markdown]
# * Change mode
# ![image.png](attachment:image.png)

# %% [markdown]
# * run it
#   1. select resolution
#     ![image.png](attachment:image.png)

# %% [markdown]
#     2. main screen
#   ![image.png](attachment:image.png)
