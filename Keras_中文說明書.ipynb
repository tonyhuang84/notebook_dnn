# %% [markdown]
# # Keras 中文說明書
# http://eighty20.cc/keras-docs-tw/other/datasets/
# https://keras-cn.readthedocs.io/en/latest/

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://wx4.sinaimg.cn/mw690/67111f6aly1fhykes5sffg207g05gdgf.gif
