# %% [markdown]
# * one epoch = one forward pass and one backward pass of all the training examples
# * batch size = the number of training examples in one forward/backward pass. The higher the batch size, the more memory space you'll need.
# * number of iterations = number of passes, each pass using [batch size] number of examples. To be clear, one pass = one forward pass + one backward pass (we do not count the forward pass and backward pass as two different passes).
#
# Example:
# if you have 1000 training examples, and your batch size is 500, then it will take 2 iterations to complete 1 epoch.

# %% [markdown]
# * 小 batch size 的優缺
#   - Advantages:
#     It requires less memory.
#     Typically networks trains faster with mini-batches.
#   - Disadvantages:
#     The smaller the batch the less accurate estimate of the gradient.
#
#  ![image.png](attachment:image.png)
#  Stochastic is just a mini-batch with batch_size equal to 1. Gradient changes its direction even more often than a mini-batch.

# %% [markdown]
# * 建議 test program [MNIST 手寫數字辨識 2 layers](http://192.168.70.143:9996/notebooks/Public/anaconda2/%5BKeras%5DMNIST%20%E6%89%8B%E5%AF%AB%E6%95%B8%E5%AD%97%E8%BE%A8%E8%AD%98%202%20layers.ipynb), 修改 batch_size 觀察每個 epoch time and loss, acc 變化
